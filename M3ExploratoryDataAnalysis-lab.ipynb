# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv"

# %%
file_name="m2_survey_data.csv"

# %%
df = pd.read_csv('file_name')

# %%
df.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# ...

# %%
#Plot the distribution curve for the column ConvertedComp.

sns.distplot(df['ConvertedComp'])
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4176\124585173.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ConvertedComp'])
# <Axes: xlabel='ConvertedComp', ylabel='Density'>

# %%
#Plot the histogram for the column ConvertedComp

plt.hist(df['ConvertedComp'])
plt.show()

# %%
#What is the median of the column ConvertedComp?

df['ConvertedComp'].median()
# Out:
# 57745.0

# %%
#How many responders identified themselves only as a Man?

Man_resp = df[['Respondent', 'Gender']].groupby('Gender').count()
Man_resp.iloc[0,0]
# Out:
# 10480

# %%
Man_resp
# Out:
#                                                     Respondent
# Gender
# Man                                                      10480
# Man;Non-binary, genderqueer, or gender non-conf...          26
# Non-binary, genderqueer, or gender non-conforming           63
# Woman                                                      731
# Woman;Man                                                    9
# Woman;Man;Non-binary, genderqueer, or gender no...           2
# Woman;Non-binary, genderqueer, or gender non-co...          14

# %%
#Find out the median ConvertedComp of responders identified themselves only as a Woman?
an_resp = df[['Respondent', 'Gender', 'ConvertedComp']].groupby('Gender').count()
an_resp.median('Gender'=='Woman')
# Out:
# Respondent       26.0
# ConvertedComp    26.0
# dtype: float64

# %%
#Give the five number summary for the column Age?

df['Age'].describe()
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %%
#Plot a histogram of the column Age.

plt.hist(df['Age'])
# Out:
# (array([2.094e+03, 5.337e+03, 2.557e+03, 8.420e+02, 2.250e+02, 4.900e+01,
#         6.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([16. , 24.3, 32.6, 40.9, 49.2, 57.5, 65.8, 74.1, 82.4, 90.7, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
#Find out if outliers exist in the column ConvertedComp using a box plot?

sns.boxplot(y='ConvertedComp', data=df)
# Out:
# <Axes: ylabel='ConvertedComp'>

# %%
df['ConvertedComp'].describe()
# Out:
# count    1.058200e+04
# mean     1.315967e+05
# std      2.947865e+05
# min      0.000000e+00
# 25%      2.686800e+04
# 50%      5.774500e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
#Find out the Inter Quartile Range for the column ConvertedComp.

Q1 = df['ConvertedComp'].quantile(0.25)
Q3 = df['ConvertedComp'].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 73132.0

# %%
#Find out the upper and lower bounds.

U_and_L = np.searchsorted(df['ConvertedComp'],73132.0)
df.iloc[U_and_L-1:U_and_L+1,:]
# Out:
#       Respondent                      MainBranch Hobbyist  \
# 5543     12146.0  I am a developer by profession      Yes
# 5544     12147.0  I am a developer by profession       No
#
#                                             OpenSourcer  \
# 5543  Less than once a month but more than once per ...
# 5544                            Less than once per year
#
#                                              OpenSource          Employment  \
# 5543  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 5544  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#         Country         Student  \
# 5543     France  Yes, part-time
# 5544  Argentina              No
#
#                                                 EdLevel  \
# 5543                 Professional degree (JD, MD, etc.)
# 5544  Some college/university study without earning ...
#
#                                          UndergradMajor  ...  \
# ...

# %%
#Identify how many outliers are there in the ConvertedComp column

outliers = df[((df['ConvertedComp']<(Q1-1.5*IQR)) | (df['ConvertedComp']>(Q3+1.5*IQR)))]

print('number of outliers:' + str(len(outliers)))
# Out:
# number of outliers:879

# %%
#Create a new dataframe by removing the outliers from the ConvertedComp column.

outliers_dropped = outliers.dropna().reset_index()
outliers_dropped
# Out:
#     index  Respondent                                         MainBranch  \
# 0      60       128.0  I am not primarily a developer, but I write co...
# 1     131       286.0                     I am a developer by profession
# 2     237       539.0                     I am a developer by profession
# 3     367       785.0                     I am a developer by profession
# 4     988      2113.0                     I am a developer by profession
# ..    ...         ...                                                ...
# 66   9623     21053.0                     I am a developer by profession
# 67   9858     21555.0                     I am a developer by profession
# 68  10230     22424.0                     I am a developer by profession
# 69  10402     22816.0                     I am a developer by profession
# 70  11264     24835.0                     I am a developer by profession
#
#    Hobbyist                                        OpenSourcer  \
# ...

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = df.select_dtypes(include=numerics)
newdf
# Out:
#        Respondent  CompTotal  ConvertedComp  WorkWeekHrs  CodeRevHrs   Age
# 0               4    61000.0        61000.0         80.0         NaN  22.0
# 1               9   138000.0        95179.0         32.0        12.0  23.0
# 2              13    90000.0        90000.0         40.0         5.0  28.0
# 3              16    29000.0       455352.0         40.0         NaN  26.0
# 4              17    90000.0        65277.0         45.0         5.0  29.0
# ...           ...        ...            ...          ...         ...   ...
# 11393       25136   130000.0       130000.0         40.0         NaN  36.0
# 11394       25137    74400.0        19880.0         40.0         5.0  25.0
# 11395       25138   105000.0       105000.0         40.0         5.0  34.0
# 11396       25141    80000.0        80371.0         42.5         2.0  25.0
# 11397       25142        NaN            NaN         80.0         1.0  30.0
#
# [11398 rows x 6 columns]

# %%
# correlation between Age and Respondent
print('correlation between Age and Respondent :', df['Age'].corr(df['Respondent']))
 
# correlation between Age and CompTotal
print('correlation between Age and CompTotal:', df['Age'].corr(df['CompTotal']))
 
# correlation between Age and ConvertedComp
print('correlation between Age and ConvertedComp :', df['Age'].corr(df['ConvertedComp']))

# correlation between Age and WorkWeekHrs
print('correlation between Age and WorkWeekHrs :', df['Age'].corr(df['WorkWeekHrs']))

# correlation between Age and CodeRevHrs
print('correlation between Age and CodeRevHrs :', df['Age'].corr(df['CodeRevHrs']))
# Out:
# correlation between Age and Respondent : 0.004041030828773931
# correlation between Age and CompTotal: 0.006969933096795743
# correlation between Age and ConvertedComp : 0.10538616072629149
# correlation between Age and WorkWeekHrs : 0.0365176490931929
# correlation between Age and CodeRevHrs : -0.020469111970030134
